# %%
import pandas as pd
df = pd.read_csv("data/all_stocks_historic.csv")

# %%
stock_in_model = df['Stock'].unique()

# %%
df2 = pd.read_csv("data/streaming_data.csv")
stocks_in_stream = df2["Stock"].unique()

# %%
for stock in stocks_in_stream:
    if stock not in stock_in_model:
        print(stock)
# Out:
# BAJAJ-AUTO

# %%
df3 = df2[df2['Stock'] != 'BAJAJ-AUTO']

# %%
df2.shape
# Out:
# (375000, 7)

# %%
df3.shape
# Out:
# (371250, 7)

# %%
df3.to_csv("data/streaming_data.csv",index=False)
